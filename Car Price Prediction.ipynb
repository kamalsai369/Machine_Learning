# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Machine Learning\CarPrice_Assignment.csv")
df
# Out:
#      car_ID  symboling                   CarName  fueltype  aspiration  \
# 0         1          3        alfa-romero giulia         0           0
# 1         2          3       alfa-romero stelvio         0           0
# 2         3          1  alfa-romero Quadrifoglio         0           0
# 3         4          2               audi 100 ls         0           0
# 4         5          2                audi 100ls         0           0
# ..      ...        ...                       ...       ...         ...
# 200     201         -1           volvo 145e (sw)         0           0
# 201     202         -1               volvo 144ea         0           1
# 202     203         -1               volvo 244dl         0           0
# 203     204         -1                 volvo 246         1           1
# 204     205         -1               volvo 264gl         0           1
#
#      doornumber      carbody drivewheel  enginelocation  wheelbase  ...  \
# 0             2  convertible        rwd               0       88.6  ...
# 1             2  convertible        rwd               0       88.6  ...
# 2             2    hatchback        rwd               0       94.5  ...
# 3             4        sedan        fwd               0       99.8  ...
# 4             4        sedan        4wd               0       99.4  ...
# ..          ...          ...        ...             ...        ...  ...
# 200           4        sedan        rwd               0      109.1  ...
# 201           4        sedan        rwd               0      109.1  ...
# 202           4        sedan        rwd               0      109.1  ...
# 203           4        sedan        rwd               0      109.1  ...
# 204           4        sedan        rwd               0      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio  horsepower  \
# 0           130        mpfi       3.47    2.68              9.0         111
# 1           130        mpfi       3.47    2.68              9.0         111
# 2           152        mpfi       2.68    3.47              9.0         154
# 3           109        mpfi       3.19    3.40             10.0         102
# 4           136        mpfi       3.19    3.40              8.0         115
# ..          ...         ...        ...     ...              ...         ...
# 200         141        mpfi       3.78    3.15              9.5         114
# 201         141        mpfi       3.78    3.15              8.7         160
# 202         173        mpfi       3.58    2.87              8.8         134
# 203         145         idi       3.01    3.40             23.0         106
# 204         141        mpfi       3.78    3.15              9.5         114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head(200)
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         0           0           2        0
# 1         2          3        3         0           0           2        0
# 2         3          1        1         0           0           2        2
# 3         4          2        4         0           0           4        3
# 4         5          2        5         0           0           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 195     196         -1      138         0           0           4        4
# 196     197         -2      140         0           0           4        3
# 197     198         -1      141         0           0           4        4
# 198     199         -2      143         0           1           4        3
# 199     200         -1      144         0           1           4        4
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0             2               0       88.6  ...         130           5
# 1             2               0       88.6  ...         130           5
# 2             2               0       94.5  ...         152           5
# 3             1               0       99.8  ...         109           5
# 4             0               0       99.4  ...         136           5
# ..          ...             ...        ...  ...         ...         ...
# 195           2               0      104.3  ...         141           5
# 196           2               0      104.3  ...         141           5
# 197           2               0      104.3  ...         141           5
# 198           2               0      104.3  ...         130           5
# 199           2               0      104.3  ...         130           5
#
#      boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68              9.0         111     5000       21
# 1         3.47    2.68              9.0         111     5000       21
# 2         2.68    3.47              9.0         154     5000       19
# 3         3.19    3.40             10.0         102     5500       24
# 4         3.19    3.40              8.0         115     5500       18
# ..         ...     ...              ...         ...      ...      ...
# 195       3.78    3.15              9.5         114     5400       23
# 196       3.78    3.15              9.5         114     5400       24
# 197       3.78    3.15              9.5         114     5400       24
# 198       3.62    3.15              7.5         162     5100       17
# 199       3.62    3.15              7.5         162     5100       17
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 195          28  13415.0
# 196          28  15985.0
# 197          28  16515.0
# 198          22  18420.0
# 199          22  18950.0
#
# [200 rows x 26 columns]

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         0           0
# 1       2          3       alfa-romero stelvio         0           0
# 2       3          1  alfa-romero Quadrifoglio         0           0
# 3       4          2               audi 100 ls         0           0
# 4       5          2                audi 100ls         0           0
#
#    doornumber      carbody drivewheel  enginelocation  wheelbase  ...  \
# 0           2  convertible        rwd               0       88.6  ...
# 1           2  convertible        rwd               0       88.6  ...
# 2           2    hatchback        rwd               0       94.5  ...
# 3           4        sedan        fwd               0       99.8  ...
# 4           4        sedan        4wd               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke compressionratio  horsepower  \
# 0         130        mpfi       3.47    2.68              9.0         111
# 1         130        mpfi       3.47    2.68              9.0         111
# 2         152        mpfi       2.68    3.47              9.0         154
# 3         109        mpfi       3.19    3.40             10.0         102
# 4         136        mpfi       3.19    3.40              8.0         115
#
#    peakrpm citympg  highwaympg    price
# 0     5000      21          27  13495.0
# 1     5000      21          27  16500.0
# 2     5000      19          26  16500.0
# 3     5500      24          30  13950.0
# 4     5500      18          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['CarName']=le.fit_transform(df['CarName'])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  \
# 0         1          3        2         0           0           2
# 1         2          3        3         0           0           2
# 2         3          1        1         0           0           2
# 3         4          2        4         0           0           4
# 4         5          2        5         0           0           4
# ..      ...        ...      ...       ...         ...         ...
# 200     201         -1      139         0           0           4
# 201     202         -1      138         0           1           4
# 202     203         -1      140         0           0           4
# 203     204         -1      142         1           1           4
# 204     205         -1      143         0           1           4
#
#          carbody drivewheel  enginelocation  wheelbase  ...  enginesize  \
# 0    convertible        rwd               0       88.6  ...         130
# 1    convertible        rwd               0       88.6  ...         130
# 2      hatchback        rwd               0       94.5  ...         152
# 3          sedan        fwd               0       99.8  ...         109
# 4          sedan        4wd               0       99.4  ...         136
# ..           ...        ...             ...        ...  ...         ...
# 200        sedan        rwd               0      109.1  ...         141
# 201        sedan        rwd               0      109.1  ...         141
# 202        sedan        rwd               0      109.1  ...         173
# 203        sedan        rwd               0      109.1  ...         145
# 204        sedan        rwd               0      109.1  ...         141
#
#      fuelsystem  boreratio  stroke compressionratio  horsepower  peakrpm  \
# 0          mpfi       3.47    2.68              9.0         111     5000
# 1          mpfi       3.47    2.68              9.0         111     5000
# 2          mpfi       2.68    3.47              9.0         154     5000
# 3          mpfi       3.19    3.40             10.0         102     5500
# 4          mpfi       3.19    3.40              8.0         115     5500
# ..          ...        ...     ...              ...         ...      ...
# 200        mpfi       3.78    3.15              9.5         114     5400
# 201        mpfi       3.78    3.15              8.7         160     5300
# 202        mpfi       3.58    2.87              8.8         134     5500
# 203         idi       3.01    3.40             23.0         106     4800
# 204        mpfi       3.78    3.15              9.5         114     5400
#
#     citympg  highwaympg    price
# 0        21          27  13495.0
# 1        21          27  16500.0
# 2        19          26  16500.0
# 3        24          30  13950.0
# 4        18          22  17450.0
# ..      ...         ...      ...
# 200      23          28  16845.0
# 201      19          25  19045.0
# 202      18          23  21485.0
# 203      26          27  22470.0
# 204      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
df['carbody']=le.fit_transform(df['carbody'])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         0           0           2        0
# 1         2          3        3         0           0           2        0
# 2         3          1        1         0           0           2        2
# 3         4          2        4         0           0           4        3
# 4         5          2        5         0           0           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         0           0           4        3
# 201     202         -1      138         0           1           4        3
# 202     203         -1      140         0           0           4        3
# 203     204         -1      142         1           1           4        3
# 204     205         -1      143         0           1           4        3
#
#     drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0          rwd               0       88.6  ...         130        mpfi
# 1          rwd               0       88.6  ...         130        mpfi
# 2          rwd               0       94.5  ...         152        mpfi
# 3          fwd               0       99.8  ...         109        mpfi
# 4          4wd               0       99.4  ...         136        mpfi
# ..         ...             ...        ...  ...         ...         ...
# 200        rwd               0      109.1  ...         141        mpfi
# 201        rwd               0      109.1  ...         141        mpfi
# 202        rwd               0      109.1  ...         173        mpfi
# 203        rwd               0      109.1  ...         145         idi
# 204        rwd               0      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio  horsepower  peakrpm citympg  \
# 0         3.47    2.68              9.0         111     5000      21
# 1         3.47    2.68              9.0         111     5000      21
# 2         2.68    3.47              9.0         154     5000      19
# 3         3.19    3.40             10.0         102     5500      24
# 4         3.19    3.40              8.0         115     5500      18
# ..         ...     ...              ...         ...      ...     ...
# 200       3.78    3.15              9.5         114     5400      23
# 201       3.78    3.15              8.7         160     5300      19
# 202       3.58    2.87              8.8         134     5500      18
# 203       3.01    3.40             23.0         106     4800      26
# 204       3.78    3.15              9.5         114     5400      19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 26 columns]

# %%
df['drivewheel']=le.fit_transform(df['drivewheel'])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         0           0           2        0
# 1         2          3        3         0           0           2        0
# 2         3          1        1         0           0           2        2
# 3         4          2        4         0           0           4        3
# 4         5          2        5         0           0           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         0           0           4        3
# 201     202         -1      138         0           1           4        3
# 202     203         -1      140         0           0           4        3
# 203     204         -1      142         1           1           4        3
# 204     205         -1      143         0           1           4        3
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0             2               0       88.6  ...         130        mpfi
# 1             2               0       88.6  ...         130        mpfi
# 2             2               0       94.5  ...         152        mpfi
# 3             1               0       99.8  ...         109        mpfi
# 4             0               0       99.4  ...         136        mpfi
# ..          ...             ...        ...  ...         ...         ...
# 200           2               0      109.1  ...         141        mpfi
# 201           2               0      109.1  ...         141        mpfi
# 202           2               0      109.1  ...         173        mpfi
# 203           2               0      109.1  ...         145         idi
# 204           2               0      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio  horsepower  peakrpm citympg  \
# 0         3.47    2.68              9.0         111     5000      21
# 1         3.47    2.68              9.0         111     5000      21
# 2         2.68    3.47              9.0         154     5000      19
# 3         3.19    3.40             10.0         102     5500      24
# 4         3.19    3.40              8.0         115     5500      18
# ..         ...     ...              ...         ...      ...     ...
# 200       3.78    3.15              9.5         114     5400      23
# 201       3.78    3.15              8.7         160     5300      19
# 202       3.58    2.87              8.8         134     5500      18
# 203       3.01    3.40             23.0         106     4800      26
# 204       3.78    3.15              9.5         114     5400      19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 26 columns]

# %%
df['fuelsystem']=le.fit_transform(df['fuelsystem'])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         0           0           2        0
# 1         2          3        3         0           0           2        0
# 2         3          1        1         0           0           2        2
# 3         4          2        4         0           0           4        3
# 4         5          2        5         0           0           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         0           0           4        3
# 201     202         -1      138         0           1           4        3
# 202     203         -1      140         0           0           4        3
# 203     204         -1      142         1           1           4        3
# 204     205         -1      143         0           1           4        3
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0             2               0       88.6  ...         130           5
# 1             2               0       88.6  ...         130           5
# 2             2               0       94.5  ...         152           5
# 3             1               0       99.8  ...         109           5
# 4             0               0       99.4  ...         136           5
# ..          ...             ...        ...  ...         ...         ...
# 200           2               0      109.1  ...         141           5
# 201           2               0      109.1  ...         141           5
# 202           2               0      109.1  ...         173           5
# 203           2               0      109.1  ...         145           3
# 204           2               0      109.1  ...         141           5
#
#      boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68              9.0         111     5000       21
# 1         3.47    2.68              9.0         111     5000       21
# 2         2.68    3.47              9.0         154     5000       19
# 3         3.19    3.40             10.0         102     5500       24
# 4         3.19    3.40              8.0         115     5500       18
# ..         ...     ...              ...         ...      ...      ...
# 200       3.78    3.15              9.5         114     5400       23
# 201       3.78    3.15              8.7         160     5300       19
# 202       3.58    2.87              8.8         134     5500       18
# 203       3.01    3.40             23.0         106     4800       26
# 204       3.78    3.15              9.5         114     5400       19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 26 columns]

# %%
df['enginetype']=le.fit_transform(df['enginetype'])
df
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         0           0           2        0
# 1         2          3        3         0           0           2        0
# 2         3          1        1         0           0           2        2
# 3         4          2        4         0           0           4        3
# 4         5          2        5         0           0           4        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         0           0           4        3
# 201     202         -1      138         0           1           4        3
# 202     203         -1      140         0           0           4        3
# 203     204         -1      142         1           1           4        3
# 204     205         -1      143         0           1           4        3
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0             2               0       88.6  ...         130           5
# 1             2               0       88.6  ...         130           5
# 2             2               0       94.5  ...         152           5
# 3             1               0       99.8  ...         109           5
# 4             0               0       99.4  ...         136           5
# ..          ...             ...        ...  ...         ...         ...
# 200           2               0      109.1  ...         141           5
# 201           2               0      109.1  ...         141           5
# 202           2               0      109.1  ...         173           5
# 203           2               0      109.1  ...         145           3
# 204           2               0      109.1  ...         141           5
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68               9.0         111     5000       21
# 1         3.47    2.68               9.0         111     5000       21
# 2         2.68    3.47               9.0         154     5000       19
# 3         3.19    3.40              10.0         102     5500       24
# 4         3.19    3.40               8.0         115     5500       18
# ..         ...     ...               ...         ...      ...      ...
# 200       3.78    3.15               9.5         114     5400       23
# 201       3.78    3.15               8.7         160     5300       19
# 202       3.58    2.87               8.8         134     5500       18
# 203       3.01    3.40              23.0         106     4800       26
# 204       3.78    3.15               9.5         114     5400       19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 26 columns]

# %%
x=df.iloc[ : , : -1].values
y=df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor 
from sklearn.metrics import r2_score

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.3, random_state=1)
regressor = DecisionTreeRegressor(random_state=0)  
regressor.fit(xtrain, ytrain)
ypred = regressor.predict(xtest)
print(r2_score(ytest, ypred) * 100)
# Out:
# 90.64307974888946
